# %%
import numpy as np

import sys
sys.path.append('./src')

# %%
from tsp import TSPInstance

# Example of Asymmetric TSP
n_cities = 4
asymmetric_tsp = TSPInstance(n_cities, asymmetric=True)
print("Asymmetric TSP Coordinates:")
print(asymmetric_tsp.coords)
print("\nAsymmetric Distance Matrix:")
print(asymmetric_tsp.dist_matrix)

# Plot the asymmetric instance
asymmetric_tsp.plot_tsp_instance()
# Out:
# Asymmetric TSP Coordinates:
# [[23.06846009 27.87109803]
#  [53.12642333 57.67877185]
#  [57.67312913 70.60375634]
#  [90.60998925 90.92532353]]
#
# Asymmetric Distance Matrix:
# [[ 0.         54.46920632 61.33673256 90.46107857]
#  [57.45378766  0.         11.7930766  45.5679119 ]
#  [50.836835   12.62290743  0.         49.51475681]
#  [98.4006036  48.74786713 35.50539707  0.        ]]
